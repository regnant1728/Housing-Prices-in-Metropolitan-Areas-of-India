# %% [markdown]
# <a href="https://colab.research.google.com/github/regnant1728/Housing-Prices-in-Metropolitan-Areas-of-India/blob/main/pandas_commands_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
 df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df.shape
# Out:
# (78, 6)

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
# 5     20
# 6     20
# 7     18
# 8     29
# 9     51
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# 16     8
# 17     4
# 18    19
# 19    29
# 20     4
# 21    33
# 22     4
# 23     2
# 24    30
# 25    35
# 26    38
# 27    45
# 28     7
# 29    21
# 30     9
# 31    22
# 32    27
# 33    18
# 34    12
# 35    28
# 36    45
# 37    20
# 38     4
# 39    18
# 40    39
# 41    13
# 42     4
# 43     5
# 44    23
# 45    25
# 46    11
# 47    11
# 48    17
# 49    17
# 50    10
# 51    20
# 52    12
# 53     5
# 54    25
# 55     2
# 56    10
# 57     3
# 58    36
# 59    12
# 60     3
# 61    13
# 62    14
# 63    29
# 64    26
# 65    36
# 66     7
# 67    17
# 68     4
# 69    28
# 70     8
# 71    12
# 72    24
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-76185366182c> in <cell line: 1>()
# ----> 1 str(salary)
#
# NameError: name 'salary' is not defined

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurtosis()
# Out:
# -0.4017126758820546

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df[['salary','phd']].mode()
# Out:
#    salary  phd
# 0   92000    4

# %%
df['salary']>100000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49     True
# 50    False
# 51     True
# 52     True
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59     True
# 60    False
# 61     True
# 62     True
# 63    False
# 64    False
# 65     True
# 66    False
# 67    False
# 68    False
# 69     True
# 70    False
# ...

# %%
df[df['salary']>150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
import pandas as pd
data = pd.read_csv('Salaries.csv')
df=pd.DataFrame(data)
df.iloc[0:3,0:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515

# %%
df.iloc[0:10,[1,2,3,5]]
# Out:
#   discipline  phd  service  salary
# 0          B   56       49  186960
# 1          A   12        6   93000
# 2          A   23       20  110515
# 3          A   40       31  131205
# 4          B   20       18  104800
# 5          A   20       20  122400
# 6          A   20       17   81285
# 7          A   18       18  126300
# 8          A   29       19   94350
# 9          A   51       51   57800

# %%
df.iloc[5,5]
# Out:
# 122400

# %%
df.loc[2,'discipline']
# Out:
# 'A'

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df=df.dropna()
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df=df.drop(columns='discipline',axis=1)
df
# Out:
#          rank  service
# 0        Prof       49
# 1        Prof        6
# 5        Prof       20
# 6   AssocProf       17
# 7        Prof       18
# ..        ...      ...
# 73       Prof       10
# 74  AssocProf        6
# 75       Prof       17
# 76       Prof       14
# 77       Prof       15
#
# [75 rows x 2 columns]

# %%
df=df.drop(index=[1,5,6],axis=0)
df
# Out:
#          rank  service
# 0        Prof       49
# 7        Prof       18
# 8        Prof       19
# 9        Prof       51
# 10       Prof       33
# ..        ...      ...
# 73       Prof       10
# 74  AssocProf        6
# 75       Prof       17
# 76       Prof       14
# 77       Prof       15
#
# [72 rows x 2 columns]

# %%
df.max ()
# Out:
# rank       Prof
# service      51
# dtype: object

# %%
df.duplicated()
# Out:
# 0     False
# 7     False
# 8     False
# 9     False
# 10    False
#       ...
# 73    False
# 74    False
# 75     True
# 76     True
# 77     True
# Length: 72, dtype: bool

# %%
df[df.duplicated()]
# Out:
#          rank  service
# 13       Prof       33
# 14       Prof       19
# 17   AsstProf        0
# 23   AsstProf        0
# 24       Prof       23
# 26       Prof       19
# 28   AsstProf        2
# 32       Prof       19
# 33       Prof       18
# 35       Prof       23
# 38   AsstProf        3
# 39       Prof       18
# 41  AssocProf        8
# 42   AsstProf        2
# 43   AsstProf        0
# 44       Prof       19
# 46   AsstProf        3
# 49       Prof       18
# 53   AsstProf        3
# 55   AsstProf        0
# 56  AssocProf        8
# 60   AsstProf        3
# 61  AssocProf       10
# 62  AssocProf        7
# 63       Prof       27
# 65       Prof       19
# 68   AsstProf        2
# 69       Prof        7
# 70   AsstProf        3
# 75       Prof       17
# 76       Prof       14
# 77       Prof       15

# %%
df.drop_duplicates()
df
# Out:
#          rank  service
# 0        Prof       49
# 7        Prof       18
# 8        Prof       19
# 9        Prof       51
# 10       Prof       33
# ..        ...      ...
# 73       Prof       10
# 74  AssocProf        6
# 75       Prof       17
# 76       Prof       14
# 77       Prof       15
#
# [72 rows x 2 columns]

# %%
df1=df.drop_duplicates()
df1.shape
# Out:
# (40, 2)

# %%
df2=df1.copy()
df2
# Out:
#          rank  service
# 0        Prof       49
# 7        Prof       18
# 8        Prof       19
# 9        Prof       51
# 10       Prof       33
# 11       Prof       23
# 12   AsstProf        0
# 15       Prof        3
# 16   AsstProf        3
# 18       Prof        7
# 19       Prof       27
# 20   AsstProf        4
# 21       Prof       30
# 22   AsstProf        2
# 25       Prof       31
# 27       Prof       43
# 29       Prof       20
# 30  AssocProf        7
# 31       Prof       21
# 34  AssocProf        8
# 36       Prof       45
# 37       Prof        8
# 40       Prof       36
# 45       Prof       25
# 47  AssocProf       11
# 48       Prof       17
# 50   AsstProf        5
# 51       Prof       14
# 52       Prof        0
# 54  AssocProf       22
# 57   AsstProf        1
# 58       Prof       26
# 59  AssocProf       10
# 64  AssocProf       24
# 66   AsstProf        6
# 67       Prof       11
# 71  AssocProf        9
# 72       Prof       15
# 73       Prof       10
# ...

# %%
print(df2.columns)
# Out:
# Index(['rank', 'service'], dtype='object')

# %%
df2['rank']
# Out:
# 0          Prof
# 7          Prof
# 8          Prof
# 9          Prof
# 10         Prof
# 11         Prof
# 12     AsstProf
# 15         Prof
# 16     AsstProf
# 18         Prof
# 19         Prof
# 20     AsstProf
# 21         Prof
# 22     AsstProf
# 25         Prof
# 27         Prof
# 29         Prof
# 30    AssocProf
# 31         Prof
# 34    AssocProf
# 36         Prof
# 37         Prof
# 40         Prof
# 45         Prof
# 47    AssocProf
# 48         Prof
# 50     AsstProf
# 51         Prof
# 52         Prof
# 54    AssocProf
# 57     AsstProf
# 58         Prof
# 59    AssocProf
# 64    AssocProf
# 66     AsstProf
# 67         Prof
# 71    AssocProf
# 72         Prof
# 73         Prof
# 74    AssocProf
# Name: rank, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
Department = pd.read_csv('Department.csv')
Department
# Out:
#    Department_ID                                    Department_Name  \
# 0      IDEPT4670                              Aerospace Engineering
# 1      IDEPT5528                     Biosciences and Bioengineering
# 2      IDEPT3115                               Chemical Engineering
# 3      IDEPT5881                                          Chemistry
# 4      IDEPT4938                                  Civil Engineering
# 5      IDEPT1423                     Computer Science & Engineering
# 6      IDEPT4132                                     Earth Sciences
# 7      IDEPT2054                             Electrical Engineering
# 8      IDEPT2357                     Energy Science and Engineering
# 9      IDEPT1537                        Humanities & Social Science
# 10     IDEPT8379                                        Mathematics
# 11     IDEPT1825                             Mechanical Engineering
# 12     IDEPT8313      Metallurgical Engineering & Materials Science
# ...

# %%
Department.head()
# Out:
#   Department_ID                 Department_Name                   DOE
# 0     IDEPT4670           Aerospace Engineering  1961-05-31T00:00:00Z
# 1     IDEPT5528  Biosciences and Bioengineering  1943-06-28T00:00:00Z
# 2     IDEPT3115            Chemical Engineering  1940-05-01T00:00:00Z
# 3     IDEPT5881                       Chemistry  2013-06-08T00:00:00Z
# 4     IDEPT4938               Civil Engineering  1941-10-27T00:00:00Z

# %%
Department.shape
# Out:
# (40, 3)

# %%
plt.hist(Department['Department_ID'])
plt.xlabel('Department_ID')
plt.ylabel('Frequency')
plt.hist(Department['Department_Name'])
plt.show()

# %%
#import library and read and define data frame and locatin of row and colounm
import pandas as pd
data = pd.read_csv('Department.csv')
df=pd.DataFrame(data)
df.iloc[5,2]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-4d111f305485> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('Department.csv')
#       3 df=pd.DataFrame(data)
#       4 df.iloc[5,2]
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
Univ= pd.read_csv('Universities.csv')
df.shape
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-603d4657c5fe> in <cell line: 6>()
#       4 Univ= pd.read_csv('Universities.csv')
#       5 df.shape
# ----> 6 data.shape
#
# NameError: name 'data' is not defined

# %%
plt.hist(Univ['Accept'])
plt.xlabel('Frequency')
plt.ylabel('Accepted')
plt.title('Histogram of Acceptance')
plt.show()

# %%
sn.histplot(Univ['Top10'])
plt.show()

# %%
sn.boxplot(Univ['SAT'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sn.distplot(Univ['SAT'])
plt.show()

# %%
plt.plot(Univ['Accept'],Univ['Top10'],'bo')
plt.xlabel('Accept')
plt.ylabel('Top10')
plt.title('Scatterplot of Top10 vs Acceptance')
plt.show()

# %%
plt.plot(Univ['Accept'],Univ['Top10'],'ys')
plt.xlabel('Accept')
plt.ylabel('Top10')
plt.title('Scatterplot of Top10 vs Acceptance')
plt.show()

# %%
plt.plot(Univ['SAT'],Univ['Top10'],'bs')
plt.xlabel('SAT')
plt.ylabel('Top10')
plt.title('Scatterplot of Top10 vs SAT')
plt.show()

# %%
sn.pairplot(Univ)

# %%
sn.pairplot(Univ.iloc[:,0:2])

# %%
sn.boxplot(Univ.iloc[:,0:4])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,6))
plt.boxplot(Univ['Accept'] ,vert=False)
plt.xlabel('Accept')
plt.ylabel('Values')
plt.title('boxplot of Accept')
plt.show()

# %%
import numpy as np
a=np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
b=np.array([[1,2,3,4],[3,4,5,6]])

# %%
type(b)
b.shape
# Out:
# (2, 4)

# %%
print(a,b)
# Out:
# [1 2 3 4] [[1 2 3 4]
#  [3 4 5 6]]

# %%
print(a /b)
# Out:
# [[1.         1.         1.         1.        ]
#  [0.33333333 0.5        0.6        0.66666667]]

# %%
print(a*b)
# Out:
# [[ 1  4  9 16]
#  [ 3  8 15 24]]

# %%
print(a+b-a)
# Out:
# [[1 2 3 4]
#  [3 4 5 6]]

# %%
b.size
# Out:
# 8

# %%
c=np.array([[1,2,3,4],[6,7,8,9]])

# %%
print(c)
# Out:
# [[1 2 3 4]
#  [6 7 8 9]]

# %%
type(c)
c.shape
# Out:
# (2, 4)

# %%
print(a+c-b)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
c=c.reshape(4,2)

# %%
# we have reshaped into 4 rows and 2 columns
print(c)
# Out:
# [[1 2]
#  [3 4]
#  [6 7]
#  [8 9]]

# %%
c=c.reshape(8,1)
print(c)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [6]
#  [7]
#  [8]
#  [9]]

# %%
#info about 0th row
c[0]
# Out:
# array([1])

# %%
a[1]
# Out:
# 2

# %%
b[1][2]
# Out:
# 5

# %%
c[1]
# Out:
# array([2])

# %%
a.sum()
# Out:
# 10

# %%
c.prod()#product of array c
# Out:
# 72576

# %%
ows

# %%
b.max()
# Out:
# 6

# %%
c.min()
# Out:
# 1

# %%
c.sum(axis=0)# axis=0 is rows
# Out:
# array([40])

# %%
c.sum(axis=1) #axix=1 is column
# Out:
# array([1, 2, 3, 4, 6, 7, 8, 9])
